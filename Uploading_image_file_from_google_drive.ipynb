# %% [markdown]
# <a href="https://colab.research.google.com/github/RemyaRS/Importing-and-Exporting-Datasets/blob/main/Uploading_image_file_from_google_drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %% [markdown]
# #Using google drive to import dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Uploading .jpg file and viewing the image

# %%
image=cv.imread(r"/content/drive/MyDrive/PUPPIES.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=2220x1478 at 0x7F50CC599810>

# %% [markdown]
# ##Uploading .png file and viewing the image

# %%
document=cv.imread(r"/content/drive/MyDrive/document.png")

# %%
cv2_imshow(document)
# Out:
# <PIL.Image.Image image mode=RGB size=540x258 at 0x7F50CC59E350>

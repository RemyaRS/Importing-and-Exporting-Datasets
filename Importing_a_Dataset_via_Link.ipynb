# %% [markdown]
# <a href="https://colab.research.google.com/github/RemyaRS/Importing-and-Exporting-File-from-Google-Colab/blob/main/Importing_a_Dataset_via_Link.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

import warnings
# Filter warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Iris Dataset

# %%
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# %%
iris =  pd.read_csv(csv_url)
iris.head(2)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa

# %% [markdown]
# But Column name of the dataset is missing

# %% [markdown]
# ![iris.PNG](data:image/png;base64,...)

# %%
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']

# %%
iris =  pd.read_csv(csv_url, names = col_names)
iris.head(2)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %% [markdown]
# #Wine Dataset

# %%
df=pd.read_csv('https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv')
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735
